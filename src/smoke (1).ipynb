# %%
from ultralytics import YOLO
from huggingface_hub import hf_hub_download
from supervision import Detections
from PIL import Image
import numpy as np
import torch
import cv2
import time

# %%
pip install opencv-python-headless numpy torch
# Out:
# Requirement already satisfied: opencv-python-headless in /home/dj/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy in /home/dj/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: torch in /home/dj/anaconda3/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: filelock in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /home/dj/anaconda3/lib/python3.12/site-packages (0.29.3)
# Requirement already satisfied: filelock in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dj/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install supervision
# Out:
# Requirement already satisfied: supervision in /home/dj/anaconda3/lib/python3.12/site-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (1.2.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (3.9.2)
# Requirement already satisfied: numpy>=1.21.2 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (4.11.0.86)
# Requirement already satisfied: pillow>=9.4 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (6.0.1)
# Requirement already satisfied: requests>=2.26.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in /home/dj/anaconda3/lib/python3.12/site-packages (from supervision) (4.66.5)
# Requirement already satisfied: cycler>=0.10 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dj/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->supervision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->supervision) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dj/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->supervision) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/dj/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
model_path = hf_hub_download(repo_id="arnabdhar/YOLOv8-Face-Detection", filename="model.pt")

# %%
model_face = YOLO(model_path)

# %%
model_smoke = YOLO(r'../training/Datasets/dataset_smoke/runs/detect/train/weights/best.pt')

# %%
def enhance_image(frame):
    # Convert to HSV (Hue, Saturation, Value)
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # Increase brightness (V channel)
    hsv[:, :, 2] = cv2.equalizeHist(hsv[:, :, 2])
    
    # Convert back to BGR
    enhanced = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return enhanced

# %%
# Start webcam
cap = cv2.VideoCapture(0)

frame_count = 0  # Counter to track the frame number
frame_skip = 4   # Only process every 4th frame
valid_detection_count = 0  # Counter for valid detections
smoking_alert = False  # Flag to indicate when a valid smoking detection occurs
alert_start_time = 0  # Track when the alert starts
alert_display_duration = 5  # Duration for alert to stay on screen (seconds)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    valid_detection = False  # Reset valid detection flag for this frame

    # Only process every 4th frame
    if frame_count % frame_skip == 0:
        # Run face detection model
        face_results = model_face(frame)
        cigarette_results = model_smoke(frame)

        # Get face bounding boxes
        face_bboxes = face_results[0].boxes.xyxy.numpy()

        # Get cigarette bounding boxes
        cigarette_bboxes = cigarette_results[0].boxes.xyxy.numpy()

        # Draw face bounding boxes
        for face_bbox in face_bboxes:
            face_x1, face_y1, face_x2, face_y2 = face_bbox
            cv2.rectangle(frame, (int(face_x1), int(face_y1)), (int(face_x2), int(face_y2)), (0, 255, 0), 2)

        # Check if a cigarette is inside a face bounding box
        for cig_bbox in cigarette_bboxes:
            cig_x1, cig_y1, cig_x2, cig_y2 = cig_bbox
            cigarette_in_face = False

            for face_bbox in face_bboxes:
                face_x1, face_y1, face_x2, face_y2 = face_bbox
                if cig_x1 >= (face_x1 - 80) and cig_y1 >= face_y1 and cig_x2 <= (face_x2 + 80) and cig_y2 <= face_y2:
                    cigarette_in_face = True
                    valid_detection = True  # Valid smoking detection in this frame
                    break
            
            # Draw bounding box (Blue if inside face, Red otherwise)
            color = (255, 0, 0) if cigarette_in_face else (0, 0, 255)
            cv2.rectangle(frame, (int(cig_x1), int(cig_y1)), (int(cig_x2), int(cig_y2)), color, 2)

    # If valid detection occurs, increment count
    if valid_detection and not smoking_alert:
        valid_detection_count += 1

    # Trigger alert after 5 valid detections
    if valid_detection_count >= 2 and not smoking_alert:
        smoking_alert = True
        alert_start_time = time.time()  # Start the alert timer
        valid_detection_count = 0  # Reset detection count after alert is triggered

    # Display alert if it's active for 10 seconds
    if smoking_alert:
        elapsed_time = time.time() - alert_start_time
        if elapsed_time < alert_display_duration:
            cv2.putText(frame, "Smoking Detected!", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3, cv2.LINE_AA)
        else:
            smoking_alert = False  # Reset alert after 10 seconds

    # Show the frame
    cv2.imshow('Face and Cigarette Detection', frame)

    # Exit when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_count += 1  # Increment frame count

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 FACE, 157.3ms
# Speed: 5.3ms preprocess, 157.3ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 627.3ms
# Speed: 1.8ms preprocess, 627.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 70
#      67         smoking_alert = False  # Reset alert after 10 seconds
#      69 # Show the frame
# ---> 70 cv2.imshow('Face and Cigarette Detection', frame)
#      72 # Exit when 'q' is pressed
#      73 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
